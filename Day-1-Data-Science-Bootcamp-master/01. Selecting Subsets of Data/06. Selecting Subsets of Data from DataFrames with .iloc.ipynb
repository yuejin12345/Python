# %% [markdown]
# # 06. Selecting Subsets of Data from DataFrames with `.iloc`
#
# # Getting started with `.iloc`
# The `.iloc` indexer is very similar to `.loc` but only uses **integer locations** to make its selections. The word `iloc` itself stands for integer location so that should help remind you what it does.
#
# Same as loc, it's int location. Do NOT put strings there.
#
# ## Simultaneous row and column subset selection with `.iloc`
# Selection with .iloc will look like the following:
#
# ```
# df.iloc[rows, cols]
# ```

# %%
import pandas as pd
df = pd.read_csv('../data/sample_data.csv', index_col=0)
df
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %% [markdown]
# ### Use a list for both rows and columns

# %%
rows = [2, 4]
cols = [0, -1] # negative starts from the end, first and the last columns 

df.iloc[rows, cols]
# Out:
#       state  score
# Aaron    FL    9.0
# Dean     AK    1.8

# %% [markdown]
# ## The possible types of selections for `.iloc`
# Row or column selections can be any of the following:
#
# * A single integer
# * A list of integers
# * A slice with integers

# %% [markdown]
# ### Slice the rows and use a list for the columns

# %%
cols = [4, 2]
df.iloc[::2, cols] # one int, a list of int or a slice of int
# ：：2 means every other row begin from the first one
# Out:
#           height    food
# Jane         165   Steak
# Aaron        120   Mango
# Dean         180  Cheese
# Cornelia     150   Beans

# %% [markdown]
# ### Use a list for the rows and a slice for the columns

# %%
rows = [5, 2, 4]
df.iloc[rows, 3:] # slice for the columns , string of the row
# Out:
#            age  height  score
# Christina   33     172    9.5
# Aaron       12     120    9.0
# Dean        32     180    1.8

# %% [markdown]
# ## Selecting some rows and all of the columns
# If you leave the column selection empty, then all of the columns will be selected.

# %%
rows = [3, 2]
df.iloc[rows]
# Out:
#          state  color   food  age  height  score
# Penelope    AL  white  Apple    4      80    3.3
# Aaron       FL    red  Mango   12     120    9.0

# %%
df.iloc[rows, :] # same, dont need the empty slice to get all the columns
# Out:
#          state  color   food  age  height  score
# Penelope    AL  white  Apple    4      80    3.3
# Aaron       FL    red  Mango   12     120    9.0

# %% [markdown]
# ## Select all of the rows and some of the columns

# %%
cols = [1, 5]
df.iloc[:, cols] # slice for the rows, a list for the columns
# Out:
#            color  score
# Jane        blue    4.6
# Niko       green    8.3
# Aaron        red    9.0
# Penelope   white    3.3
# Dean        gray    1.8
# Christina  black    9.5
# Cornelia     red    2.2

# %% [markdown]
# ## Cannot do this with *just the brackets*
# Just the brackets does select columns but it only understands **labels** and not **integer location**.

# %%
cols = [1, 5]
df[cols] # cannot do int local for [], just labels/strings/column names
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-bad534172234> in <module>()
#       1 cols = [1, 5]
# ----> 2 df[cols]
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: '[1 5] not in index'

# %% [markdown]
# ## Select some rows and a single column
# Note that a Series is returned whenever a single row or column is selected.

# %%
rows = [2, 3, 5]
cols = 4

df.iloc[rows, cols] # a series
# Out:
# Aaron        120
# Penelope      80
# Christina    172
# Name: height, dtype: int64

# %% [markdown]
# ## A trick to select a single row row or column as a DataFrame and NOT a Series
# You can select a single row (or column) and return a DataFrame and not a Series if you use a list to make the selection.

# %%
rows = [2, 3, 5]
cols = [4]           # one item list 

df.iloc[rows, cols]  # keep the dataframe, one col df
# Out:
#            height
# Aaron         120
# Penelope       80
# Christina     172

# %% [markdown]
# ## Select a single row as a Series with `.iloc`
# By passing a single integer to `.iloc`, it will select one row as a Series:

# %%
df.iloc[2] # select second row of data
# Out:
# state        FL
# color       red
# food      Mango
# age          12
# height      120
# score         9
# Name: Aaron, dtype: object

# %% [markdown]
# # Summary of `.iloc`
# Is the exact same as `.loc` but uses **integer location** only for selection. The official Pandas documentation refers to this as selection by **position**.

# %% [markdown]
# # Exericses

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">Select the rows with integer location 10, 5, and 1</span>

# %%
# your code here
movie = pd.read_csv('../data/movie.csv', index_col= 'title')
movie.head(2)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
#
#                                           director_fb       actor1  actor1_fb  \
# title
# Avatar                                            0.0  CCH Pounder     1000.0
# Pirates of the Caribbean: At World's End        563.0  Johnny Depp    40000.0
#
#                                                     actor2  actor2_fb  \
# title
# Avatar                                    Joel David Moore      936.0
# Pirates of the Caribbean: At World's End     Orlando Bloom     5000.0
#
#                                              ...     actor3_fb        gross  \
# title                                        ...
# Avatar                                       ...         855.0  760505847.0
# Pirates of the Caribbean: At World's End     ...        1000.0  309404152.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
#
# [2 rows x 21 columns]

# %%
# your code here
rows = [10, 5 ,1]
movie.iloc[rows]
# Out:
#                                             year  color content_rating  \
# title
# Batman v Superman: Dawn of Justice        2016.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Batman v Superman: Dawn of Justice           183.0     Zack Snyder
# John Carter                                  132.0  Andrew Stanton
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
#
#                                           director_fb        actor1  \
# title
# Batman v Superman: Dawn of Justice                0.0  Henry Cavill
# John Carter                                     475.0  Daryl Sabara
# Pirates of the Caribbean: At World's End        563.0   Johnny Depp
#
#                                           actor1_fb           actor2  \
# title
# Batman v Superman: Dawn of Justice          15000.0     Lauren Cohan
# John Carter                                   640.0  Samantha Morton
# Pirates of the Caribbean: At World's End    40000.0    Orlando Bloom
#
#                                           actor2_fb     ...     actor3_fb  \
# title                                                   ...
# Batman v Superman: Dawn of Justice           4000.0     ...        2000.0
# John Carter                                   632.0     ...         530.0
# Pirates of the Caribbean: At World's End     5000.0     ...        1000.0
#
#                                                 gross  \
# title
# Batman v Superman: Dawn of Justice        330249062.0
# John Carter                                73058679.0
# Pirates of the Caribbean: At World's End  309404152.0
#
#                                                             genres  \
# title
# Batman v Superman: Dawn of Justice         Action|Adventure|Sci-Fi
# John Carter                                Action|Adventure|Sci-Fi
# Pirates of the Caribbean: At World's End  Action|Adventure|Fantasy
#
#                                          num_reviews  num_voted_users  \
# title
# Batman v Superman: Dawn of Justice             673.0           371639
# John Carter                                    462.0           212204
# Pirates of the Caribbean: At World's End       302.0           471220
#
#                                                                               plot_keywords  \
# title
# Batman v Superman: Dawn of Justice        based on comic book|batman|sequel to a reboot|...
# John Carter                               alien|american civil war|male nipple|mars|prin...
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
#
#                                          language country       budget  \
# title
# Batman v Superman: Dawn of Justice        English     USA  250000000.0
# John Carter                               English     USA  263700000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
#
#                                           imdb_score
# title
# Batman v Superman: Dawn of Justice               6.9
# John Carter                                      6.6
# Pirates of the Caribbean: At World's End         7.1
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Select the columns with integer location 10, 5, and 1</span>

# %%
# your code here
col = [10, 5, 1]
movie.iloc[:, col]
# Out:
#                                                            actor3  \
# title
# Avatar                                                  Wes Studi
# Pirates of the Caribbean: At World's End           Jack Davenport
# Spectre                                          Stephanie Sigman
# The Dark Knight Rises                        Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                    NaN
# John Carter                                          Polly Walker
# Spider-Man 3                                        Kirsten Dunst
# Tangled                                               M.C. Gainey
# Avengers: Age of Ultron                        Scarlett Johansson
# Harry Potter and the Half-Blood Prince               Rupert Grint
# Batman v Superman: Dawn of Justice                 Alan D. Purwin
# Superman Returns                                   Frank Langella
# Quantum of Solace                                    Rory Kinnear
# Pirates of the Caribbean: Dead Man's Chest         Jack Davenport
# The Lone Ranger                                     Tom Wilkinson
# Man of Steel                                         Harry Lennix
# The Chronicles of Narnia: Prince Caspian           Damián Alcázar
# The Avengers                                   Scarlett Johansson
# Pirates of the Caribbean: On Stranger Tides        Stephen Graham
# Men in Black 3                                 Nicole Scherzinger
# The Hobbit: The Battle of the Five Armies           James Nesbitt
# The Amazing Spider-Man                                Chris Zylka
# Robin Hood                                           Scott Grimes
# The Hobbit: The Desolation of Smaug                 James Nesbitt
# The Golden Compass                           Kristin Scott Thomas
# King Kong                                              Evan Parke
# Titanic                                             Gloria Stuart
# Captain America: Civil War                            Chris Evans
# Battleship                                         Tadanobu Asano
# Jurassic World                                            Omar Sy
# ...                                                           ...
# Manito                                            Casper Martinez
# Rampage                                              Michael Paré
# Slacker                                             Jean Caffeine
# Dutch Kills                                           Damon Owlia
# Dry Spell                                            Travis Legge
# Flywheel                                         Janet Lee Dapper
# Exeter                                          Lindsay MacDonald
# The Ridges                                        Brandon Landers
# The Puffy Chair                                        Bari Hyman
# Stories of Our Lives                               Mugambi Nthiga
# Breaking Upwards                               Ebon Moss-Bachrach
# All Superheroes Must Die                            Nick Principe
# Pink Flamingos                                       Edith Massey
# Clean                                                Don McKellar
# The Circle                                       Mojgan Faramarzi
# Tin Can Man                                      Emma Eliza Regan
# The Cure                                                   Denden
# On the Downlow                                        Eric Ambriz
# Sanctuary; Quite a Conundrum                           John Lucas
# Bang                                                  James Noble
# Primer                                               Casey Gooden
# Cavite                                                  Quynn Ton
# El Mariachi                                        Consuelo Gómez
# The Mongol King                                    Sara Stepnicka
# Newlyweds                                         Daniella Pineda
# Signed Sealed Delivered                              Crystal Lowe
# The Following                                       Sam Underwood
# A Plague So Pleasant                               David Chandler
# Shanghai Calling                                      Eliza Coupe
# My Date with Drew                                        Jon Gunn
#
#                                              director_fb            color
# title
# Avatar                                               0.0            Color
# Pirates of the Caribbean: At World's End           563.0            Color
# Spectre                                              0.0            Color
# The Dark Knight Rises                            22000.0            Color
# Star Wars: Episode VII - The Force Awakens         131.0              NaN
# John Carter                                        475.0            Color
# Spider-Man 3                                         0.0            Color
# Tangled                                             15.0            Color
# Avengers: Age of Ultron                              0.0            Color
# Harry Potter and the Half-Blood Prince             282.0            Color
# Batman v Superman: Dawn of Justice                   0.0            Color
# Superman Returns                                     0.0            Color
# Quantum of Solace                                  395.0            Color
# Pirates of the Caribbean: Dead Man's Chest         563.0            Color
# The Lone Ranger                                    563.0            Color
# Man of Steel                                         0.0            Color
# The Chronicles of Narnia: Prince Caspian            80.0            Color
# The Avengers                                         0.0            Color
# Pirates of the Caribbean: On Stranger Tides        252.0            Color
# Men in Black 3                                     188.0            Color
# The Hobbit: The Battle of the Five Armies            0.0            Color
# The Amazing Spider-Man                             464.0            Color
# Robin Hood                                           0.0            Color
# The Hobbit: The Desolation of Smaug                  0.0            Color
# The Golden Compass                                 129.0            Color
# King Kong                                            0.0            Color
# Titanic                                              0.0            Color
# Captain America: Civil War                          94.0            Color
# Battleship                                         532.0            Color
# Jurassic World                                     365.0            Color
# ...                                                  ...              ...
# Manito                                               3.0            Color
# Rampage                                            892.0            Color
# Slacker                                              0.0  Black and White
# Dutch Kills                                          0.0            Color
# Dry Spell                                          138.0            Color
# Flywheel                                           589.0            Color
# Exeter                                             158.0            Color
# The Ridges                                           8.0              NaN
# The Puffy Chair                                    157.0            Color
# Stories of Our Lives                                 0.0  Black and White
# Breaking Upwards                                    38.0            Color
# All Superheroes Must Die                            91.0            Color
# Pink Flamingos                                       0.0            Color
# Clean                                              107.0            Color
# The Circle                                         397.0            Color
# Tin Can Man                                         18.0  Black and White
# The Cure                                            62.0            Color
# On the Downlow                                       5.0            Color
# Sanctuary; Quite a Conundrum                       120.0            Color
# Bang                                                 3.0            Color
# Primer                                             291.0            Color
# Cavite                                               0.0            Color
# El Mariachi                                          0.0            Color
# The Mongol King                                      2.0            Color
# Newlyweds                                            0.0            Color
# Signed Sealed Delivered                              2.0            Color
# The Following                                        NaN            Color
# A Plague So Pleasant                                 0.0            Color
# Shanghai Calling                                     0.0            Color
# My Date with Drew                                   16.0            Color
#
# [4916 rows x 3 columns]

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Select rows with integer location 100 to but not including 105 along with the column integer location 5.</span>

# %%
# your code here
rows = 100: 105
col = 5
movie.iloc[rows, col]
# Out:
#   File "<ipython-input-23-8af6b4ab9683>", line 2
#     rows = 100: 105
#               ^
# SyntaxError: invalid syntax

# %%
# your code here
movie.iloc[100: 105, 5]
# Out:
# title
# The Fast and the Furious                   357.0
# The Curious Case of Benjamin Button      21000.0
# X-Men: First Class                         905.0
# The Hunger Games: Mockingjay - Part 2      508.0
# The Sorcerer's Apprentice                  226.0
# Name: director_fb, dtype: float64

# %% [markdown]
# # Continue making selections with `.iloc` below

# %%
# your code here
movie.iloc[::1, 2].head(5)
# Out:
# title
# Avatar                                        PG-13
# Pirates of the Caribbean: At World's End      PG-13
# Spectre                                       PG-13
# The Dark Knight Rises                         PG-13
# Star Wars: Episode VII - The Force Awakens      NaN
# Name: content_rating, dtype: object

# %%
movie.iloc[:, 1:10:2].head(5) #starts with the second and ends with 10th (not including 10), step is 2
# ::1 = :
# Out:
#                                             color  duration  director_fb  \
# title
# Avatar                                      Color     178.0          0.0
# Pirates of the Caribbean: At World's End    Color     169.0        563.0
# Spectre                                     Color     148.0          0.0
# The Dark Knight Rises                       Color     164.0      22000.0
# Star Wars: Episode VII - The Force Awakens    NaN       NaN        131.0
#
#                                             actor1_fb  actor2_fb
# title
# Avatar                                         1000.0      936.0
# Pirates of the Caribbean: At World's End      40000.0     5000.0
# Spectre                                       11000.0      393.0
# The Dark Knight Rises                         27000.0    23000.0
# Star Wars: Episode VII - The Force Awakens      131.0       12.0

# %%
movie.iloc[1, :].loc['year']
# Out:
# 2007.0

# %%
movie.loc[:,'year'].iloc[1]
# Out:
# 2007.0
