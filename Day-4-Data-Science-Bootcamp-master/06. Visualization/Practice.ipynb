# %%
import pandas as pd

# %%
flights = pd.read_csv('../data/flights.csv')
flights.head()
# Out:
#    year  month  day  day_of_week airline  flight_number tail_number  \
# 0  2015      1    1            4      WN           1908      N8324A
# 1  2015      1    1            4      UA            581      N448UA
# 2  2015      1    1            4      MQ           2851      N645MQ
# 3  2015      1    1            4      AA            383      N3EUAA
# 4  2015      1    1            4      WN           3047      N560WN
#
#   origin_airport destination_airport  scheduled_departure      ...        \
# 0            LAX                 SLC                 1625      ...
# 1            DEN                 IAD                  823      ...
# 2            DFW                 VPS                 1305      ...
# 3            DFW                 DCA                 1555      ...
# 4            LAX                 MCI                 1720      ...
#
#    arrival_time  arrival_delay  diverted  cancelled  cancellation_reason  \
# ...

# %%
flights.shape
# Out:
# (58492, 31)

# %% [markdown]
# P1: filter data, finding things we care about from these data
# Find all flights from Houston
#
# P2: Count the frequencies

# %%
# Find all Houston flights
filt = flights['origin_airport'] == 'IAH'
flights[filt].head()
# Out:
#     year  month  day  day_of_week airline  flight_number tail_number  \
# 5   2015      1    1            4      UA            225      N447UA
# 9   2015      1    1            4      UA           1223      N14237
# 14  2015      1    1            4      UA            259      N838UA
# 27  2015      1    1            4      OO           5219      N746SK
# 33  2015      1    1            4      AA           2227      N016AA
#
#    origin_airport destination_airport  scheduled_departure      ...        \
# 5             IAH                 SAN                 1450      ...
# 9             IAH                 SJC                  925      ...
# 14            IAH                 IND                 1426      ...
# 27            IAH                 JAC                 1104      ...
# 33            IAH                 MIA                 1935      ...
#
#     arrival_time  arrival_delay  diverted  cancelled  cancellation_reason  \
# ...

# %%
# Find average delay for flights leaving from Housotn in June
filt1 = flights['origin_airport'] == 'IAH'
filt2 = flights['month'] == 6
f2 = flights[filt1 & filt2]
f2.head()
# Out:
#        year  month  day  day_of_week airline  flight_number tail_number  \
# 25972  2015      6    1            1      UA           1408      N33266
# 25973  2015      6    1            1      OO           6211      N706SK
# 25976  2015      6    1            1      EV           4650      N14179
# 25992  2015      6    1            1      EV           4264      N11526
# 25995  2015      6    1            1      EV           4275      N27190
#
#       origin_airport destination_airport  scheduled_departure      ...        \
# 25972            IAH                 TPA                 1016      ...
# 25973            IAH                 SAT                 1637      ...
# 25976            IAH                 TUS                  915      ...
# 25992            IAH                 HRL                  911      ...
# 25995            IAH                 CRP                 1912      ...
#
#        arrival_time  arrival_delay  diverted  cancelled  cancellation_reason  \
# ...

# %%
f2['departure_delay'].mean()
# Out:
# 19.43198090692124

# %%
# Q1: percent of flights got delayed deaprture from Houston or arrive at Houston in the first half year jan-june 2015
filt1 = (flights['origin_airport'] == 'IAH') | (flights['destination_airport'] == 'IAH')
filt2 = flights['month'].isin([1,2,3,4,5,6])
filt3 = flights['arrival_delay'] > 0
filt = filt1 & filt2 & filt3
f1 = flights[filt]
f1.shape[0]
# Out:
# 1277

# %%
f1.departure_delay.mean()
# Out:
# 31.466718872357088

# %%
# Q2: Check flight EK212 in 2015
flights['flight_number'] = 'EK212'

# %%
filt1 = flights['origin_airport'] == 'IAH'
filt2 = flights['destination_airport'] == 'ORD'
filt3 = flights['year'] == 2015
f2 = flights[filt1 & filt2 & filt3] 
f2.head()
# Out:
#       year  month  day  day_of_week airline flight_number tail_number  \
# 177   2015      1    2            5      UA         EK212      N26226
# 586   2015      1    4            7      UA         EK212      N38467
# 719   2015      1    5            1      UA         EK212      N854UA
# 1230  2015      1    8            4      UA         EK212      N67812
# 1519  2015      1   10            6      UA         EK212      N69833
#
#      origin_airport destination_airport  scheduled_departure      ...        \
# 177             IAH                 ORD                 1535      ...
# 586             IAH                 ORD                 1935      ...
# 719             IAH                 ORD                  715      ...
# 1230            IAH                 ORD                  920      ...
# 1519            IAH                 ORD                 1425      ...
#
#       arrival_time  arrival_delay  diverted  cancelled  cancellation_reason  \
# ...

# %%
f2.groupby('flight_number').agg({'origin_airport':'count'})
# Out:
#                origin_airport
# flight_number
# EK212                     129

# %%
# Q3: Which airport has the most flights?
f3 = flights.groupby('origin_airport').agg({'flight_number':'count'})
f3.head()
# Out:
#                 flight_number
# origin_airport
# ATL                     10413
# DEN                      5857
# DFW                      7121
# IAH                      4384
# LAS                      4019

# %%
f3_2 = flights.groupby('destination_airport').agg({'flight_number':'count'})
f3_2.head()
# Out:
#                      flight_number
# destination_airport
# ABE                             55
# ABI                             74
# ABQ                            343
# ABR                             19
# ABY                             19

# %%
f3_3 = pd.concat([f3, f3_2], axis=1, sort=False) # full outer join
f3_3
# Out:
#      flight_number  flight_number
# ATL        10413.0           1326
# DEN         5857.0           1581
# DFW         7121.0           1454
# IAH         4384.0            946
# LAS         4019.0           1439
# LAX         5889.0           1991
# MSP         3410.0           1001
# ORD         8394.0           1634
# PHX         4603.0           1297
# SFO         4402.0           1637
# ABE            NaN             55
# ABI            NaN             74
# ABQ            NaN            343
# ABR            NaN             19
# ABY            NaN             19
# ACT            NaN             49
# ACV            NaN             40
# ACY            NaN              9
# AEX            NaN            109
# AGS            NaN             83
# ALB            NaN             76
# ALO            NaN             17
# AMA            NaN             86
# ANC            NaN             96
# ASE            NaN             95
# ATW            NaN             76
# ...

# %%
f3_3.iloc[:,0] + f3_3.iloc[:,1] # f3.add(f3_2, fill_value = 0)
# Out:
# ATL    11739.0
# DEN     7438.0
# DFW     8575.0
# IAH     5330.0
# LAS     5458.0
# LAX     7880.0
# MSP     4411.0
# ORD    10028.0
# PHX     5900.0
# SFO     6039.0
# ABE        NaN
# ABI        NaN
# ABQ        NaN
# ABR        NaN
# ABY        NaN
# ACT        NaN
# ACV        NaN
# ACY        NaN
# AEX        NaN
# AGS        NaN
# ALB        NaN
# ALO        NaN
# AMA        NaN
# ANC        NaN
# ASE        NaN
# ATW        NaN
# AUS        NaN
# AVL        NaN
# AVP        NaN
# AZO        NaN
#         ...
# SJC        NaN
# SJT        NaN
# SJU        NaN
# SLC        NaN
# SMF        NaN
# SMX        NaN
# SNA        NaN
# SPI        NaN
# SPS        NaN
# SRQ        NaN
# STL        NaN
# STT        NaN
# SUN        NaN
# SUX        NaN
# SYR        NaN
# TLH        NaN
# TOL        NaN
# TPA        NaN
# TRI        NaN
# TTN        NaN
# TUL        NaN
# TUS        NaN
# TVC        NaN
# TXK        NaN
# TYR        NaN
# TYS        NaN
# VLD        NaN
# VPS        NaN
# ...

# %%
(f3_3.iloc[:,0] + f3_3.iloc[:,1]).dropna()
# Out:
# ATL    11739.0
# DEN     7438.0
# DFW     8575.0
# IAH     5330.0
# LAS     5458.0
# LAX     7880.0
# MSP     4411.0
# ORD    10028.0
# PHX     5900.0
# SFO     6039.0
# Name: flight_number, dtype: float64

# %%
f3.add(f3_2, fill_value = 0).head()
# Out:
#      flight_number
# ABE           55.0
# ABI           74.0
# ABQ          343.0
# ABR           19.0
# ABY           19.0

# %%
f3.merge(f3_2, left_index = True, right_index = True)
# Out:
#      flight_number_x  flight_number_y
# ATL            10413             1326
# DEN             5857             1581
# DFW             7121             1454
# IAH             4384              946
# LAS             4019             1439
# LAX             5889             1991
# MSP             3410             1001
# ORD             8394             1634
# PHX             4603             1297
# SFO             4402             1637

# %%
f3_4 = pd.concat([f3, f3_2], axis=0, sort=False)
f3_4.head()# then groupby sum
# Out:
#      flight_number
# ATL          10413
# DEN           5857
# DFW           7121
# IAH           4384
# LAS           4019

# %%
# Q4: Make a column datatime
flights.head()
# Out:
#    year  month  day  day_of_week airline flight_number tail_number  \
# 0  2015      1    1            4      WN         EK212      N8324A
# 1  2015      1    1            4      UA         EK212      N448UA
# 2  2015      1    1            4      MQ         EK212      N645MQ
# 3  2015      1    1            4      AA         EK212      N3EUAA
# 4  2015      1    1            4      WN         EK212      N560WN
#
#   origin_airport destination_airport  scheduled_departure      ...        \
# 0            LAX                 SLC                 1625      ...
# 1            DEN                 IAD                  823      ...
# 2            DFW                 VPS                 1305      ...
# 3            DFW                 DCA                 1555      ...
# 4            LAX                 MCI                 1720      ...
#
#    arrival_time  arrival_delay  diverted  cancelled  cancellation_reason  \
# 0        2010.0           65.0         0          0                  NaN
# ...

# %%
flights['time'] = flights['year'].astype(str) + '/' + flights['month'].astype(str) +'/' +  flights['day'].astype(str)

# %%
flights.head()
# Out:
#    year  month  day  day_of_week airline flight_number tail_number  \
# 0  2015      1    1            4      WN         EK212      N8324A
# 1  2015      1    1            4      UA         EK212      N448UA
# 2  2015      1    1            4      MQ         EK212      N645MQ
# 3  2015      1    1            4      AA         EK212      N3EUAA
# 4  2015      1    1            4      WN         EK212      N560WN
#
#   origin_airport destination_airport  scheduled_departure    ...     \
# 0            LAX                 SLC                 1625    ...
# 1            DEN                 IAD                  823    ...
# 2            DFW                 VPS                 1305    ...
# 3            DFW                 DCA                 1555    ...
# 4            LAX                 MCI                 1720    ...
#
#    arrival_delay  diverted  cancelled  cancellation_reason  air_system_delay  \
# 0           65.0         0          0                  NaN              31.0
# ...

# %%
flights['time1'] = pd.to_datetime(flights['time'], format='%Y/%m/%d')

# %%
flights.dtypes
# Out:
# year                            int64
# month                           int64
# day                             int64
# day_of_week                     int64
# airline                        object
# flight_number                  object
# tail_number                    object
# origin_airport                 object
# destination_airport            object
# scheduled_departure             int64
# departure_time                float64
# departure_delay               float64
# taxi_out                      float64
# wheels_off                    float64
# scheduled_time                float64
# elapsed_time                  float64
# air_time                      float64
# distance                        int64
# wheels_on                     float64
# taxi_in                       float64
# scheduled_arrival               int64
# arrival_time                  float64
# arrival_delay                 float64
# diverted                        int64
# cancelled                       int64
# ...

# %%
# Q5: Which date has the most flights and in that day which airport have the most flights?
f5 = flights.groupby('time1').agg({'flight_number':'count'})
f5.head()
# Out:
#             flight_number
# time1
# 2015-01-01            136
# 2015-01-02            171
# 2015-01-03            182
# 2015-01-04            177
# 2015-01-05            180

# %%
f5.sort_values('flight_number', ascending=False).head()
# Out:
#             flight_number
# time1
# 2015-06-15            226
# 2015-06-07            222
# 2015-07-13            220
# 2015-08-13            215
# 2015-04-20            213

# %%
filt = flights['time1'] == '2015-06-15'
filt.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: time1, dtype: bool

# %%
f5_2 = flights[filt]
f5_2.head()
# Out:
#        year  month  day  day_of_week airline flight_number tail_number  \
# 28611  2015      6   15            1      WN         EK212      N7706A
# 28612  2015      6   15            1      NK         EK212      N613NK
# 28613  2015      6   15            1      DL         EK212      N6710E
# 28614  2015      6   15            1      VX         EK212      N626VA
# 28615  2015      6   15            1      EV         EK212      N844AS
#
#       origin_airport destination_airport  scheduled_departure    ...      \
# 28611            PHX                 CLE                 1340    ...
# 28612            ORD                 LAX                  625    ...
# 28613            LAX                 SLC                 1315    ...
# 28614            SFO                 AUS                 1130    ...
# 28615            ATL                 GPT                 1750    ...
#
#        diverted  cancelled  cancellation_reason  air_system_delay  \
# ...

# %%
date_max1=flights.groupby(['time1','origin_airport']).agg({'flight_number':'count'}).reset_index()
date_max1.columns=['Date','airport','counts']

# %%
date_max1.sort_values(by='counts', ascending=False).head()
# Out:
#            Date airport  counts
# 890  2015-03-31     ATL      47
# 2690 2015-09-27     ATL      46
# 1090 2015-04-20     ATL      46
# 1400 2015-05-21     ATL      46
# 2220 2015-08-11     ATL      45

# %%
# Q6:
